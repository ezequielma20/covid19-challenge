# %%
import numpy as np 
import pandas as pd 
import glob
import json

# %%
#Indico la ruta donde se encuentra el set de datos descargados
root_path = 'D:/DS/COVID/CORD19'
# root_path = 'C:\\Users\\emarellano\\Documents\\Ezequiel\\Cursos\\CORD-19-research-challenge\\2020-03-13'

#archivo con metadata
metadata_path = f'{root_path}/metadata.csv'

#leo el archivo con metadata
meta_df = pd.read_csv(metadata_path, dtype={
    'pubmed_id': str,
    'Microsoft Academic Paper ID': str, 
    'doi': str
})

# %%
#armo un listado con los archivos json que tienen las noticias
all_json = glob.glob(f'{root_path}/**/*.json', recursive=True)
len(all_json)
# Out:
# 29315

# %%
#creo un dataframe donde voy a guardar las columnas de interes:
#sha: id de la noticia
#title: titulo de la noticia
#body_text: cuerpo de la noticia
df = pd.DataFrame(columns = ['sha', 'title', 'abstract', 'body_text'])

# %%
#Leo cada json y lo agrego al dataframe
for json_path in all_json:
   with open(json_path) as file:
            content = json.load(file)
            sha = content['paper_id']
            title = content['metadata']['title']
            abstract = []
            body_text = []
            # Abstract
            for entry in content['abstract']:
                abstract.append(entry['text'])
            # Body text
            for entry in content['body_text']:
                body_text.append(entry['text'])
            abstract = '\n'.join(abstract)
            body_text = '\n'.join(body_text)
            row = [(sha, title, abstract, body_text)]
            dfRow = pd.DataFrame(row, columns = ['sha', 'title', 'abstract', 'body_text'])
            df = pd.concat([dfRow, df], ignore_index=True, sort=False)

# %%
result = pd.merge(df,
                 meta_df,
                 on='sha', 
                 how='outer')

# %%
# Guardo el dataframe en un csv para levantarlo desde cualquier script
result_path = f'{root_path}/result.csv'
result.to_csv(result_path, index=False)

# %% [markdown]
# ### Calidad de datos
# Los registros que tienen has_full_text son los que deberian tener un archivo json.
#
# Buscar duplicados por body_text y abstract.

# %%
meta_df.describe()

# %%
print(meta_df.isnull().sum(axis=0))

print('\nCon full text: ', len(meta_df[meta_df['has_full_text']]))

# %%
df.describe()
# Out:
#                                              sha  title abstract  \
# count                                      29315  29315    29315
# unique                                     29315  25114    21050
# top     c6e2851ef1f6e35c2954eeaa913f2da2502842d9
# freq                                           1   3583     8051
#
#                                                 body_text
# count                                               29315
# unique                                              29117
# top     In previous reports, workers have characterize...
# freq                                                    4

# %%
print('Estan en metadata pero no tienen un json: ', len(meta_df[(~meta_df['sha'].isin(df['sha']) & (~meta_df['title'].isin(df['title'])))]))
print('Tienen un json pero no estan en metadata: ', len(df[(~df['sha'].isin(meta_df['sha']) & (~df['title'].isin(meta_df['title'])))]))
# Out:
# Estan en metadata pero no tienen un json:  15521
# Tienen un json pero no estan en metadata:  1048

# %%
result.isnull().sum(axis=0)
# Out:
# sha                            15758
# title_x                        16530
# abstract_x                     16530
# body_text                      16530
# source_x                        1637
# title_y                         1861
# doi                             5107
# pmcid                          22538
# pubmed_id                      22914
# license                         1637
# abstract_y                     10051
# publish_time                   11660
# authors                         4783
# journal                        12684
# Microsoft Academic Paper ID    44893
# WHO #Covidence                 44090
# has_full_text                   1637
# full_text_file                 13028
# dtype: int64

# %%
print('Tienen el mismo abstract: ', len(result.loc[result['abstract_x']==result['abstract_y']][['abstract_x','abstract_y']]))
print('Tienen el mismo title: ', len(result.loc[result['title_x']==result['title_y']][['title_x','title_y']]))
result.loc[result['title_x']!=result['title_y']][['title_x','title_y']]
# Out:
# Tienen el mismo abstract:  2108
# Tienen el mismo title:  14619
#                                                  title_x  \
# 0      Supplemental material for the paper "Evidence ...
# 2      Identification of a Subdomain of CENPB That Is...
# 3      Brief Definitive Report MACROPHAGES GENETICALL...
# 9      STATE OF THE ART 1B-H3-01 Current perspectives...
# 10     Effect of acetate Ringer ' s solution with or ...
# ...                                                  ...
# 45852                                                NaN
# 45853                                                NaN
# 45854                                                NaN
# 45855                                                NaN
# 45856                                                NaN
#
#                                                  title_y
# 0                                                    NaN
# 2      Identification of a subdomain of CENP-B that i...
# 3      Macrophages genetically resistant to mouse hep...
# 9      Current perspectives in transfusion-transmitte...
# 10     Effect of acetate Ringer(’)s solution with or ...
# ...                                                  ...
# 45852  Potential role of inanimate surfaces for the s...
# 45853  The Healthy Infant Nasal Transcriptome: A Benc...
# 45854  The intrinsic vulnerability of networks to epi...
# 45855  Lung ultrasound as a diagnostic tool for radio...
# 45856  Viral etiology of hospitalized acute lower res...
#
# [31238 rows x 2 columns]

# %% [markdown]
# ### Busco duplicados

# %%
(result[(df['body_text'].notnull()) 
        & (result.duplicated('body_text', keep=False))].sort_values(by=['body_text','sha','doi']))
# Out:
#                                             sha  \
# 27270  220fbe1f5e79e25737c0624de9a4245bfee48ec0
# 25245  59b5d767e4bb03b049a800c82c2e78edd0650907
# 2122   182fc0c38ce9f98fa70dc7ed3063551d426c4b7a
# 1547   58b5c77c9fb3f68a3ad84a3f15275dc0e4554192
# 2055   1fe9d44383ae2debf062555ea05a816dd3848a91
# ...                                         ...
# 15827  34ba72963a44bbe5ce71b7ec96c6f71dd1069c2e
# 354    d7732a3cb93e9f48792f9072956ef244552afca1
# 54     fa46fb0587956a218b9b81d5aa6b2a6c7ec68126
# 1759   4050a72fdcfdeddecf74c01047934871e72abd8e
# 1216   7acb13da2225f2c681714a69df8d7787d3312203
#
#                                                  title_x  \
# 27270  Complete genome sequence of canine astrovirus ...
# 25245  Complete genome sequence of canine astrovirus ...
# 2122                            To appear in: One Health
# 1547                            To appear in: One Health
# 2055   Challenges presented by MERS corona virus, and...
# ...                                                  ...
# 15827  574 Coronavirus NL63 Illnesses in Infancy are ...
# 354
# 54
# 1759        Emerging Zoonoses: the "One Health Approach"
# 1216        Emerging Zoonoses: the "One Health Approach"
#
#                                               abstract_x  \
# 27270
# 25245
# 2122
# 1547
# 2055   Numerous viral infections have arisen and affe...
# ...                                                  ...
# 15827  RATIONALE: In infancy, rhinovirus illnesses an...
# 354
# 54
# 1759   Zoonoses represent a public health risk recent...
# 1216   Zoonoses represent a public health risk recent...
#
#                                                body_text  source_x  \
# 27270  , but to date, no full-length genome sequence ...       NaN
# 25245  , but to date, no full-length genome sequence ...       NaN
# 2122   . The WHO have announced that the disease caus...       NaN
# 1547   . The WHO have announced that the disease caus...       NaN
# 2055   . These two viruses are causing acute and ofte...       NaN
# ...                                                  ...       ...
# 15827  p 5 0.005) prevalence in children who needed t...  Elsevier
# 354    where did you receive your training and what m...       NaN
# 54     where did you receive your training and what m...       NaN
# 1759   www.e-shaw.org at predicting the risk of an ep...       NaN
# 1216   www.e-shaw.org at predicting the risk of an ep...       NaN
#
#                                                  title_y  \
# 27270                                                NaN
# 25245                                                NaN
# 2122                                                 NaN
# 1547                                                 NaN
# 2055                                                 NaN
# ...                                                  ...
# 15827  Coronavirus NL63 Illnesses in Infancy are a Ri...
# 354                                                  NaN
# 54                                                   NaN
# 1759                                                 NaN
# 1216                                                 NaN
#
#                               doi pmcid pubmed_id    license abstract_y  \
# 27270                         NaN   NaN       NaN        NaN        NaN
# 25245                         NaN   NaN       NaN        NaN        NaN
# 2122                          NaN   NaN       NaN        NaN        NaN
# 1547                          NaN   NaN       NaN        NaN        NaN
# 2055                          NaN   NaN       NaN        NaN        NaN
# ...                           ...   ...       ...        ...        ...
# 15827  10.1016/j.jaci.2006.11.508   NaN       NaN  els-covid        NaN
# 354                           NaN   NaN       NaN        NaN        NaN
# 54                            NaN   NaN       NaN        NaN        NaN
# 1759                          NaN   NaN       NaN        NaN        NaN
# 1216                          NaN   NaN       NaN        NaN        NaN
#
#       publish_time                                            authors  \
# 27270          NaN                                                NaN
# 25245          NaN                                                NaN
# 2122           NaN                                                NaN
# 1547           NaN                                                NaN
# 2055           NaN                                                NaN
# ...            ...                                                ...
# 15827   2007-01-31  Pappas, T.E.; Sullivan Dille, K.T.; Lee, W.; G...
# 354            NaN                                                NaN
# 54             NaN                                                NaN
# 1759           NaN                                                NaN
# 1216           NaN                                                NaN
#
#                                           journal Microsoft Academic Paper ID  \
# 27270                                         NaN                         NaN
# 25245                                         NaN                         NaN
# 2122                                          NaN                         NaN
# 1547                                          NaN                         NaN
# 2055                                          NaN                         NaN
# ...                                           ...                         ...
# 15827  Journal of Allergy and Clinical Immunology                         NaN
# 354                                           NaN                         NaN
# 54                                            NaN                         NaN
# 1759                                          NaN                         NaN
# 1216                                          NaN                         NaN
#
#       WHO #Covidence has_full_text  full_text_file
# 27270            NaN           NaN             NaN
# 25245            NaN           NaN             NaN
# 2122             NaN           NaN             NaN
# 1547             NaN           NaN             NaN
# 2055             NaN           NaN             NaN
# ...              ...           ...             ...
# 15827            NaN          True  custom_license
# 354              NaN           NaN             NaN
# 54               NaN           NaN             NaN
# 1759             NaN           NaN             NaN
# 1216             NaN           NaN             NaN
#
# [410 rows x 18 columns]

# %%
# meta_df[(meta_df['title'].notnull()) & (meta_df.duplicated(['title'], keep=False)) 
#         & (meta_df.duplicated(['sha'], keep=False)) & (meta_df.duplicated(['abstract'], keep=False))
#         & (meta_df.duplicated(['doi'], keep=False))
#        ].sort_values(by='title')
# Out:
# 1048

# %% [markdown]
# #### sha y body_text duplicados
# Son documentos donde se incluye mas de una investigacion, por lo tanto tienen distintos DOI, distintos titulos y distintos autores, pero el body_text incluye todos los articulos.
#
# - Concatenar todos los titulos en uno?
# - Buscar la forma de separar el body_text para cada caso?
#
# Como son solo 19 tomaria el approach mas simple.
# Si dejo los repetidos se corre el riesgo de sesgar los resultados?

# %%
len(result[(result.duplicated('sha', keep=False)) & (result.duplicated('body_text', keep=False))].sort_values(by=['sha','doi']))
# Out:
# 19

# %%
# print(df.loc[df['sha'] == '72a5640aa0c307fbe171ca7ad55d3fda48b53988']['title'][11736])
meta_df.loc[meta_df['sha'] == '72a5640aa0c307fbe171ca7ad55d3fda48b53988']['title']
# meta_df.loc[meta_df['doi'] == '10.1186/cc2504']
# Out:
# 28931    Computerised tomography (CT) in severe acute r...
# 28932    Critically ill patients with severe acute resp...
# 28933    Retrospective analysis of critically ill patie...
# 28934    Increase in methicillin-resistant Staphylococc...
# Name: title, dtype: object
